# %% [markdown]
# <a href="https://colab.research.google.com/github/Isnup/TensorFLOWlite/blob/TensorFlow-C/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tflite-runtime
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from google.colab import files
from tflite_runtime.interpreter import Interpreter
import requests

# Função para carregar imagens de uma pasta local
# (Essa função é mantida igual)
def load_images_from_local(folder_path, label):
    images = []
    labels = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.jpg') or file_name.endswith('.png'):
            img_path = os.path.join(folder_path, file_name)
            img = tf.image.decode_image(tf.io.read_file(img_path))
            img = tf.image.resize(img, [128, 128])
            img = img / 255.0
            images.append(img)
            labels.append(label)
    return images, labels

# Função para carregar e preprocessar a imagem
# (Essa função é mantida igual)
def load_and_preprocess_image(image_data):
    img = tf.image.decode_image(image_data)
    img = tf.image.resize(img, [128, 128])
    img = img / 255.0
    return img

# Função para análise da imagem
# (Essa função é mantida igual)
def analyze_image(image_data):
    # Carregar e preprocessar a imagem
    input_image = load_and_preprocess_image(image_data)
    input_image = np.expand_dims(input_image, axis=0).astype(np.float32)

    # Executar inferência na imagem carregada
    interpreter.set_tensor(input_details[0]['index'], input_image)
    interpreter.invoke()

    # Obter resultado
    output_data = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output_data[0])

    # Imprimir o resultado como "CAIXA COMPLETA" ou "CAIXA INCOMPLETA"
    result = "CAIXA COMPLETA" if predicted_label == 0 else "CAIXA INCOMPLETA"
    print(result)

    # Exibir a imagem analisada
    plt.imshow(input_image[0])
    plt.title(result)
    plt.axis('off')
    plt.show()

# Função para fazer upload da imagem usando requests
def upload_image():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        # Pega o conteúdo binário da imagem
        with open(file_name, "rb") as f:
            image_data = f.read()
        return image_data

# Carregar o modelo TensorFlow Lite já treinado
interpreter = Interpreter(model_path="model.tflite")  # Carrega o modelo
interpreter.allocate_tensors()

# Obter detalhes das entradas e saídas
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Loop para permitir o upload e análise repetidos da imagem
while True:
    # Fazer upload da imagem usando requests
    image_data = upload_image()

    # Analisar a imagem
    analyze_image(image_data)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 17.9 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-3e4a913e-d85e-437e-abb7-007978095510" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e4a913e-d85e-437e-abb7-007978095510">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
